# %% [markdown]
# ![image.png](attachment:c1dd4aca-1cea-44e0-afdb-8555e4ce986a.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
a =-1;b=-2;x=2*np.sqrt(3);y=-np.sqrt(3);alpfa=np.pi/6
x1 = (x-a)*np.cos(-alpfa)-(y-b)*np.sin(-alpfa)
y1 = (y-b)*np.cos(-alpfa)+(x-a)*np.sin(-alpfa)
print('Answers:',x1,y1)
x2 = x1*np.cos(alpfa)+y1*np.sin(alpfa)-a
y2 = y1*np.cos(alpfa)-x1*np.sin(alpfa)-b
print('Проверка:',x2,y2)
plt.arrow(-1, 0, 4, 0, width=0.08, color='black')
plt.arrow(0, -2, 0, 5, width=0.08, color='black')
x3 = np.cos(-alpfa); y3 = - np.sin(-alpfa)
x4 = np.sin(-alpfa); y4 = np.cos(-alpfa)
plt.arrow(-1, -2, x3*3, y3*3, width=0.08, color='blue')
plt.arrow(-1, -2, x4*3, y4*3, width=0.08, color='blue')
plt.plot(x, y, 'or')
plt.text(x + 0.2, y, 'M')
plt.xlabel('x'); plt.ylabel('y')
plt.axis('equal')
plt.grid()
plt.show()
# Out:
# Answers: 4.0 -1.9999999999999993
# Проверка: 3.4641016151377553 -1.7320508075688767

# %% [markdown]
# ![image.png](attachment:29aac8c5-9baa-418b-a302-785cd39e3c37.png)

# %%
from sympy import *
a=3;b=2;xM=1;yM=-2
x1,y1,alfa = symbols('x1 y1 alfa')
x = (x1-a) * cos(alfa) - (y1-b) * sin(alfa)
y = (y1-b) * cos(alfa) + (x1-a) * sin(alfa)
f = y - 2 * x +4
y2 = solve(f,y1)
print('решение системы:',y2)
# Out:
# решение системы: [(-x1*sin(alfa) + 2*x1*cos(alfa) + 7*sin(alfa) - 4*cos(alfa) - 4)/(2*sin(alfa) + cos(alfa))]

# %%
y1 = (-x1*sin(alfa) + 2*x1*cos(alfa) + 7*sin(alfa) - 4*cos(alfa) - 4)/(2*sin(alfa) + cos(alfa))
yy = y1.subs(alfa, pi / 4)
print('Уравнение повернутой прямой:', yy)
# Out:
# Уравнение повернутой прямой: sqrt(2)*(sqrt(2)*x1/2 - 4 + 3*sqrt(2)/2)/3

# %%
alfa=np.pi/4
xN = xM * np.cos(-alfa) - yM * np.sin(-alfa)+a
yN = yM * np.cos(-alfa) + xM * np.sin(-alfa)+b

# %%
x = np.linspace(-80,80,13)
y3 = plt.plot(x,2*x-4,'-.m')
y4 = plt.plot(x,np.sqrt(2)*(np.sqrt(2)*x/2 - 4 + 3*np.sqrt(2)/2)/3,'-b')
plt.plot(1,-2,'or')
plt.plot(xN,yN,'or')
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.grid()
alpfa = np.pi/4
x3 = np.cos(-alpfa); y3 = - np.sin(-alpfa)
x4 = np.sin(-alpfa); y4 = np.cos(-alpfa)
plt.arrow(3, 2, x3*5, y3*5, width=0.08, color='red')
plt.arrow(3, 2, x4*5, y4*5, width=0.08, color='red')
plt.axis([-10,10,-10,10])
# Out:
# (-10.0, 10.0, -10.0, 10.0)

# %% [markdown]
# ![image.png](attachment:7bb74efa-608e-4473-81e0-e030198926bd.png)

# %%
alfa2 = np.pi/4
A = np.matrix([[np.cos(-alfa2), -np.sin(-alfa2)], [np.sin(-alfa), np.cos(-alfa)]])
B = np.matrix([[3],[2]])
X1 = np.matrix([[1],[-2]])
X = A*X1+B
print(X)
# Out:
# [[ 2.29289322]
#  [-0.12132034]]

# %%
alfa1 = np.pi/6
A1 = np.matrix([[np.cos(-alfa1), -np.sin(-alfa1)], [np.sin(-alfa1), np.cos(-alfa1)]])
X11 = np.matrix([[2*np.sqrt(3)+1],[-sqrt(3)+2]])
X = A1*X11
print(X)
# Out:
# [[4.86602540378444 - 0.5*sqrt(3)]
#  [-0.866025403784439*sqrt(3) - 0.499999999999999]]

# %% [markdown]
# ![image.png](attachment:f5b3b997-da1a-4b0b-9fad-4bce8a974d71.png)

# %%
A=(2,2);B=(4,2);C=(2,4);D=(4,4);alfa=np.pi/4;a=3;b=2
xA=(A[0]-a)*np.cos(-alfa)-(A[1]-b)*np.sin(alfa)
yA=(A[1]-b)*np.cos(-alpfa)+(A[0]-a)*np.cos(alfa)
xB=(B[0]-a)*np.cos(-alfa)-(B[1]-b)*np.sin(alfa)
yB=(B[1]-b)*np.cos(-alpfa)+(B[0]-a)*np.cos(alfa)
xC=(C[0]-a)*np.cos(-alfa)-(C[1]-b)*np.sin(alfa)
yC=(C[1]-b)*np.cos(-alpfa)+(C[0]-a)*np.cos(alfa)
xD=(D[0]-a)*np.cos(-alfa)-(D[1]-b)*np.sin(alfa)
yD=(D[1]-b)*np.cos(-alpfa)+(D[0]-a)*np.cos(alfa)
Xk = [xA,xB,xD,xC,xA]
Yk = [yA,yB,yD,yC,yA]
plt.plot(Xk,Yk)
x = [2,4,4,2,2]
y = [2,2,4,4,2]
plt.plot(x,y,'m')
plt.grid()
plt.axis([-4,5,-4,5])
OSxx = np.cos(-alfa);OSxy = -np.sin(-alfa)
OSyx = np.cos(-alfa);OSyy = np.sin(-alfa)
plt.arrow(3,2,OSxx*7,OSxy*7,width=0.08, color='red')
plt.arrow(3,2,OSyy*7,OSyx*7,width=0.08, color='red')
plt.axhline(y=0,color='black')
plt.axvline(x=0,color='black')

# %% [markdown]
# ![image.png](attachment:84f9db28-af24-46d1-83c7-aef4fa923dbf.png)

# %%
M = Point(1,-2)
A = Point(3,2)
L = Line(M,A)
L.rotate(pi/4,M).equation()
# Out:
# -3*sqrt(2)*x - sqrt(2)*y + sqrt(2)
