# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %% [markdown]
# ![image.png](attachment:95a25b4d-2ab7-4984-8079-9b41ef510744.png)

# %%
# n-ая степень

# %% [markdown]
# ![image.png](attachment:c23b7105-ba7b-447e-af6c-2e69d9aeca9e.png)

# %%
print('N(x0) = f(x0)+f(x0;x1)*(x0-x0)+f(x0;x1;x2)*(x0-x0)*(x0-x1)+...+f(x0;x1;x1;...;xn)*(x0-x0)*(x0-x1)*(x0-x2)*...*(x0-xn)')
print('N(x1) = f(x0)+f(x0;x1)*(x1-x0)+f(x0;x1;x2)*(x1-x0)*(x1-x1)+...+f(x0;x1;x1;...;xn)*(x1-x0)*(x1-x1)*(x1-x2)*...*(x1-xn)')
print('N(x2) = f(x0)+f(x0;x1)*(x2-x0)+f(x0;x1;x2)*(x2-x0)*(x2-x1)+...+f(x0;x1;x1;...;xn)*(x2-x0)*(x2-x1)*(x2-x2)*...*(x2-xn)')
# Out:
# N(x0) = f(x0)+f(x0;x1)*(x0-x0)+f(x0;x1;x2)*(x0-x0)*(x0-x1)+...+f(x0;x1;x1;...;xn)*(x0-x0)*(x0-x1)*(x0-x2)*...*(x0-xn)
# N(x1) = f(x0)+f(x0;x1)*(x1-x0)+f(x0;x1;x2)*(x1-x0)*(x1-x1)+...+f(x0;x1;x1;...;xn)*(x1-x0)*(x1-x1)*(x1-x2)*...*(x1-xn)
# N(x2) = f(x0)+f(x0;x1)*(x2-x0)+f(x0;x1;x2)*(x2-x0)*(x2-x1)+...+f(x0;x1;x1;...;xn)*(x2-x0)*(x2-x1)*(x2-x2)*...*(x2-xn)

# %% [markdown]
# ![image.png](attachment:9225be1a-b114-45b9-a6af-db533f1993af.png)

# %%
# сумма 
x = [*range(100)]
n = 0
Nom = range(len(x))
for i in Nom:
    n += len(x[:-1])
    del x[-1]
n
# Out:
# 4950

# %% [markdown]
# ![image.png](attachment:79c0244c-b715-4f64-9f1c-b55dd242d3e5.png)

# %%
p = [6,5,1]
x = 1
N = (p[0]*(x)**2+p[1]*(x)+p[2])

# %% [markdown]
# ![image.png](attachment:52f064e0-2ea1-4bc8-8287-e72cf1c60a74.png)

# %%
p = lambda x:6*x**2+5*x+1
x = 1
p(x)
# Out:
# 12

# %% [markdown]
# ![image.png](attachment:f8a25778-4abf-47e4-acfd-ed41e5f57acb.png)

# %%
x = sp.symbols('x')
x = 1
p = 6*x**2+5*x+1
print(p)
# Out:
# 12

# %% [markdown]
# ![image.png](attachment:4eb1b275-47c6-4791-9b76-f63cd62aea02.png)

# %%
x = [1,2,3,4,5,7,9,10]
divided_difference(x,1,2,lambda x: x**2)
# Out:
# 3.0  - разделенная разность первого порядка

# %%
x = [1,2,3,4,5,7,9,10]
divided_difference(x,2,3,lambda x: x**2)
# Out:
# 5.0  - разделенная разность первого порядка
# 7.0  - разделенная разность первого порядка
# 1.0  - разделенная разность порядка 2

# %% [markdown]
# ![image.png](attachment:c09f5e34-09d0-41b5-bb69-fbe310bd34b9.png)

# %% [markdown]
# ![image.png](attachment:14e0c91d-ece4-4d9a-b716-25ca23562517.png)

# %%
X = np.linspace(1,10,6)
X_funk = np.linspace(1,10,100)
Y = np.e**X
Y_funk = np.e**X_funk
x = sp.symbols('x')
f = sp.E**x
coeffs_newton(X,Y,f,X_funk,Y_funk)
# Out:
# 7.625758301465556  - разделенная разность первого порядка
# 46.133149372687065  - разделенная разность первого порядка
# 279.0892901278601  - разделенная разность первого порядка
# 1688.3918163668166  - разделенная разность первого порядка
# 10214.175270819082  - разделенная разность первого порядка
# 10.696497519783753  - разделенная разность порядка 2
# 64.71003909865918  - разделенная разность порядка 2
# 391.47292395526574  - разделенная разность порядка 2
# 2368.273181792296  - разделенная разность порядка 2
# Следующий порядок =  3
# 10.002507699791744  - разделенная разность порядка 3
# 60.511645343816035  - разделенная разность порядка 3
# 366.07412182167224  - разделенная разность порядка 3
# Следующий порядок =  4
# 7.015158006114485  - разделенная разность порядка 4
# 42.439232844146694  - разделенная разность порядка 4
# Следующий порядок =  5
# 3.9360083153369123  - разделенная разность порядка 5
# ...
